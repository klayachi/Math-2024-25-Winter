# %% [markdown]
# <a href="https://colab.research.google.com/github/klayachi/Math-2024-25-Winter/blob/main/Notebooks_EN/02_Analytic_Geometry/05_Lines/exercise_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tasks related to equations of lines on a plane
# ##**Visualize each task:** - Python, GeoGebra, Wolfram Alpha, ...
#
# 1- The line passes through points A(1,2) and B(3,4). Find the equation of the line.
#
# 2- The line passes through point A(1,2) and is parallel to the line y=2x+3. Find the equation of the line.
#
# 3- The line passes through point A(1,2) and is perpendicular to the line y=2x+3. Find the equation of the line.
#
# 4- We have two lines y=2x+3 and y=3x+2. Find the intersection point of these lines and calculate the angle between them.
#
# 5- Write the equation of the line passing through point A(1,2) and parallel to the vector v→=[2,3].
#
# 6- We have the line y=2x+3. Find an example of a line perpendicular and parallel to it.
#
# 7- We have the line y=2x+3 and point A(1,2). Find the distance from point A to the line.
#
# 8- The line intersects the coordinate axes at points A(2,0) and B(0,3). Find the equation of the line.
#
# 9- Calculate the angle between the line y=x+3 and the Ox axis.
#
# 10- Provide a vector perpendicular to the line x+y+1=0.

# %% [markdown]
# #**HomeWork :**

# %% [markdown]
# # Task 1: Line Through Points $A(1,2)$ and $B(3,4)$
#
# 1. **Calculate the Slope**:
#    The slope of the line, $m$, is given by:
#    $$
#    m = \frac{y_2 - y_1}{x_2 - x_1}
#    $$
#    Substituting $A(1, 2)$ and $B(3, 4)$:
#    $$
#    m = \frac{4 - 2}{3 - 1} = \frac{2}{2} = 1
#    $$
#
# 2. **Write the Equation**:
#    Using the point-slope form:
#    $$
#    y - y_1 = m(x - x_1)
#    $$
#    Substitute $m = 1$, $x_1 = 1$, and $y_1 = 2$:
#    $$
#    y - 2 = 1(x - 1)
#    $$
#
# 3. **Simplify**:
#    Expand and simplify to get:
#    $$
#    y = x + 1
#    $$
#
# **Final Answer**: The equation of the line is $y = x + 1$.
#
# **Visualisation** : https://www.geogebra.org/calculator/hzxhf83r
#
# ---
#
# # Task 2: Line Through $A(1,2)$ Parallel to $y = 2x + 3$
#
# 1. **Determine the Slope**:
#    For parallel lines, the slopes are equal. Since the slope of $y = 2x + 3$ is $m = 2$, the required line also has $m = 2$.
#
# 2. **Write the Equation**:
#    Using the point-slope form:
#    $$
#    y - y_1 = m(x - x_1)
#    $$
#    Substitute $m = 2$, $x_1 = 1$, and $y_1 = 2$:
#    $$
#    y - 2 = 2(x - 1)
#    $$
#
# 3. **Simplify**:
#    Expand and simplify:
#    $$
#    y = 2x
#    $$
#
# **Final Answer**: The equation of the line is $y = 2x$.
#
# ---
#
# # Task 3: Line Through $A(1,2)$ Perpendicular to $y = 2x + 3$
#
# 1. **Determine the Perpendicular Slope**:
#    For perpendicular lines, the slopes satisfy:
#    $$
#    m \cdot m_\perp = -1
#    $$
#    Substituting $m = 2$:
#    $$
#    2 \cdot m_\perp = -1 \implies m_\perp = -\frac{1}{2}
#    $$
#
# 2. **Write the Equation**:
#    Using the point-slope form:
#    $$
#    y - y_1 = m_\perp(x - x_1)
#    $$
#    Substitute $m_\perp = -\frac{1}{2}$, $x_1 = 1$, and $y_1 = 2$:
#    $$
#    y - 2 = -\frac{1}{2}(x - 1)
#    $$
#
# 3. **Simplify**:
#    Expand and simplify:
#    $$
#    y = -\frac{1}{2}x + \frac{5}{2}
#    $$
#
# **Final Answer**: The equation of the line is $y = -\frac{1}{2}x + \frac{5}{2}$.
#
# **Visualisation** : https://www.geogebra.org/calculator/enfkspad
#
# ---
#
# # Task 4: Intersection of $y = 2x + 3$ and $y = 3x + 2$
#
# 1. **Find the Intersection Point**:
#    Solve the system of equations:
#    $$
#    2x + 3 = 3x + 2
#    $$
#    Rearrange:
#    $$
#    x = 1, \, y = 5
#    $$
#
# 2. **Calculate the Angle Between the Lines**:
#    The angle $\theta$ between two lines with slopes $m_1$ and $m_2$ is given by:
#    $$
#    \tan \theta = \left| \frac{m_1 - m_2}{1 + m_1m_2} \right|
#    $$
#    Substituting $m_1 = 2$ and $m_2 = 3$:
#    $$
#    \tan \theta = \left| \frac{2 - 3}{1 + 2 \cdot 3} \right| = \frac{1}{7}
#    $$
#
# **Final Answer**:
# - Intersection point: $(1, 5)$.
# - Angle: $\tan^{-1}\left(\frac{1}{7}\right)$.
#
# **Visualisation** : https://www.geogebra.org/graphing/qgupbcze
#
# ---
#
# # Task 5: Line Through $A(1,2)$ Parallel to $\vec{v} = [2,3]$
#
# 1. **Determine the Slope**:
#    The direction vector $\vec{v} = [2, 3]$ gives:
#    $$
#    m = \frac{3}{2}
#    $$
#
# 2. **Write the Equation**:
#    Using the point-slope form:
#    $$
#    y - y_1 = m(x - x_1)
#    $$
#    Substitute $m = \frac{3}{2}$, $x_1 = 1$, and $y_1 = 2$:
#    $$
#    y - 2 = \frac{3}{2}(x - 1)
#    $$
#
# 3. **Simplify**:
#    Expand and simplify:
#    $$
#    y = \frac{3}{2}x + \frac{1}{2}
#    $$
#
# **Final Answer**: The equation of the line is $y = \frac{3}{2}x + \frac{1}{2}$.
#
# https://www.geogebra.org/graphing/xdsa4uyv
#
# ---
#
# # Task 6: Parallel and Perpendicular Lines to $y = 2x + 3$
#
# 1. **Parallel**:
#    $$
#    y = 2x - 4
#    $$
#
# 2. **Perpendicular**:
#    $$
#    y = -\frac{1}{2}x + 1
#    $$
#
# **Final Answer**: Examples are $y = 2x - 4$ (parallel) and $y = -\frac{1}{2}x + 1$ (perpendicular).
#
# ---
#
# # Task 7: Distance From $A(1,2)$ to $y = 2x + 3$
#
# 1. **Distance Formula**:
#    The distance $d$ from $(x_1, y_1)$ to a line $ax + by + c = 0$ is:
#    $$
#    d = \frac{|ax_1 + by_1 + c|}{\sqrt{a^2 + b^2}}
#    $$
#    Substituting $a = 2$, $b = -1$, $c = 3$, $x_1 = 1$, and $y_1 = 2$:
#    $$
#    d = \frac{|2(1) - 2 + 3|}{\sqrt{2^2 + (-1)^2}} = \frac{3}{\sqrt{5}}
#    $$
#
# **Final Answer**: The distance is $\frac{3}{\sqrt{5}}$.
#
# ---
#
# # Task 8: Line Through $A(2,0)$ and $B(0,3)$
#
# 1. **Calculate the Slope**:
#    $$
#    m = \frac{3 - 0}{0 - 2} = -\frac{3}{2}
#    $$
#
# 2. **Write the Equation**:
#    Using $y = mx + c$, find $c$:
#    $$
#    0 = -\frac{3}{2}(2) + c \implies c = 3
#    $$
#
# 3. **Final Equation**:
#    $$
#    y = -\frac{3}{2}x + 3
#    $$
#
# **Final Answer**: The equation of the line is $y = -\frac{3}{2}x + 3$.
#
# ---
#
# # Task 9: Angle Between $y = x + 3$ and the $x$-Axis
#
# 1. **Angle**:
#    $$
#    \theta = \tan^{-1}(m) = \tan^{-1}(1) = 45^\circ
#    $$
#
# **Final Answer**: The angle is $45^\circ$.
#
# ---
#
# # Task 10: Vector Perpendicular to $x + y + 1 = 0$
#
# 1. **Perpendicular Vector**:
#    The normal vector to the line is $\nabla f = [1, 1]$. A vector perpendicular to this line is:
#    $$
#    \vec{v} = [-1, 1]
#    $$
#
# **Final Answer**: A perpendicular vector is $\vec{v} = [-1, 1]$.
