# %% [markdown]
# <a href="https://colab.research.google.com/github/klayachi/Math-2024-25-Winter/blob/main/Notebooks_EN/02_Analytic_Geometry/06_Conic_Curves/exercise_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Tasks related to conic sections
#
# **Visualize each task.** - Python, GeoGebra, Wolfram Alpha, ...
#
# * Find the equation of a circle with center at point $A(1,2)$ and radius $r=3$.
# * Find the equation of a parabola intersecting the $Ox$ axis at points $x=2$, $x=4$, and passing through point $y(3)=1$.
# * Find the center of the ellipse with the equation $x^2 + 4y^2 - 4x - 16y + 16 = 0$.
# * Find the slope ($m>0$) of the line $y=mx-5$ that is tangent to the circle with the equation $x^2 + y^2=1$.
# * Find the intersection points of the hyperbola $x^2 - y^2 = 1$ with the ellipse's line $x^2 + 4y^2 = 6$.
# * For the given hyperbola $x^2 - y^2 = 1$, find the distance between its branches.

# %% [markdown]
# #**HomeWork :**

# %% [markdown]
# ## Task 1: Equation of a Circle with Center $A(1,2)$ and Radius $r=3$
#
# 1. **Standard Form of a Circle**:
#    The equation of a circle with center $(h, k)$ and radius $r$ is:
#    $$
#    (x - h)^2 + (y - k)^2 = r^2
#    $$
#
# 2. **Substitute the Given Values**:
#    Here, $h = 1$, $k = 2$, and $r = 3$:
#    $$
#    (x - 1)^2 + (y - 2)^2 = 3^2
#    $$
#
# 3. **Simplify**:
#    $$
#    (x - 1)^2 + (y - 2)^2 = 9
#    $$
#
# **Final Answer**: The equation of the circle is:
# $$
# (x - 1)^2 + (y - 2)^2 = 9
# $$
#
# ---
#
# ## Task 2: Equation of a Parabola Intersecting $Ox$ at $x=2$, $x=4$, Passing Through $y(3)=1$
#
# 1. **General Equation**:
#    For a parabola intersecting the $x$-axis at points $x_1$ and $x_2$, the equation is:
#    $$
#    y = a(x - x_1)(x - x_2)
#    $$
#
# 2. **Substitute $x_1 = 2$ and $x_2 = 4$**:
#    $$
#    y = a(x - 2)(x - 4)
#    $$
#
# 3. **Find $a$ Using the Given Point $y(3) = 1$**:
#    Substitute $x = 3$ and $y = 1$:
#    $$
#    1 = a(3 - 2)(3 - 4)
#    $$
#    Simplify:
#    $$
#    1 = a(1)(-1) \implies a = -1
#    $$
#
# 4. **Write the Equation**:
#    Substitute $a = -1$:
#    $$
#    y = -(x - 2)(x - 4)
#    $$
#
# 5. **Simplify**:
#    Expand:
#    $$
#    y = -(x^2 - 6x + 8) \implies y = -x^2 + 6x - 8
#    $$
#
# **Final Answer**: The equation of the parabola is:
# $$
# y = -x^2 + 6x - 8
# $$
#
# ---
#
# ## Task 3: Center of the Ellipse $x^2 + 4y^2 - 4x - 16y + 16 = 0$
#
# 1. **Group Terms**:
#    Rearrange:
#    $$
#    (x^2 - 4x) + (4y^2 - 16y) = -16
#    $$
#
# 2. **Complete the Square**:
#    - For $x^2 - 4x$: Add and subtract $\left(\frac{-4}{2}\right)^2 = 4$:
#      $$
#      x^2 - 4x + 4 = (x - 2)^2
#      $$
#    - For $4y^2 - 16y$: Factor out $4$ and complete the square:
#      $$
#      4(y^2 - 4y + 4) = 4(y - 2)^2
#      $$
#
# 3. **Rewrite the Equation**:
#    $$
#    (x - 2)^2 + 4(y - 2)^2 = 4
#    $$
#
# 4. **Find the Center**:
#    The center is $(h, k) = (2, 2)$.
#
# **Final Answer**: The center of the ellipse is $(2, 2)$.
#
# ---
#
# ## Task 4: Slope ($m > 0$) of $y = mx - 5$ Tangent to Circle $x^2 + y^2 = 1$
#
# 1. **Substitute Line into Circle**:
#    Substitute $y = mx - 5$ into $x^2 + y^2 = 1$:
#    $$
#    x^2 + (mx - 5)^2 = 1
#    $$
#
# 2. **Expand and Simplify**:
#    $$
#    x^2 + m^2x^2 - 10mx + 25 = 1
#    $$
#    Combine terms:
#    $$
#    (1 + m^2)x^2 - 10mx + 24 = 0
#    $$
#
# 3. **Tangency Condition**:
#    For the line to be tangent, the discriminant $\Delta$ of the quadratic equation must be $0$:
#    $$
#    \Delta = b^2 - 4ac
#    $$
#    Here, $a = 1 + m^2$, $b = -10m$, and $c = 24$. Substituting:
#    $$
#    (-10m)^2 - 4(1 + m^2)(24) = 0
#    $$
#    Simplify:
#    $$
#    100m^2 - 96 - 96m^2 = 0
#    $$
#    $$
#    4m^2 = 96 \implies m^2 = 24 \implies m = \sqrt{24} = 2\sqrt{6}
#    $$
#
# **Final Answer**: The slope is $m = 2\sqrt{6}$.
#
# ---
#
# ## Task 5: Intersection Points of $x^2 - y^2 = 1$ and $x^2 + 4y^2 = 6$
#
# 1. **Express $x^2$ from $x^2 - y^2 = 1$**:
#    $$
#    x^2 = y^2 + 1
#    $$
#
# 2. **Substitute into $x^2 + 4y^2 = 6$**:
#    $$
#    (y^2 + 1) + 4y^2 = 6
#    $$
#    Simplify:
#    $$
#    5y^2 + 1 = 6 \implies 5y^2 = 5 \implies y^2 = 1
#    $$
#
# 3. **Solve for $y$**:
#    $$
#    y = \pm 1
#    $$
#
# 4. **Find $x$**:
#    Substituting $y = \pm 1$ into $x^2 = y^2 + 1$:
#    $$
#    x^2 = 1 + 1 = 2 \implies x = \pm \sqrt{2}
#    $$
#
# 5. **Intersection Points**:
#    The points are $(\sqrt{2}, 1)$, $(-\sqrt{2}, 1)$, $(\sqrt{2}, -1)$, and $(-\sqrt{2}, -1)$.
#
# **Final Answer**: The intersection points are:
# $$
# (\sqrt{2}, 1), \, (-\sqrt{2}, 1), \, (\sqrt{2}, -1), \, (-\sqrt{2}, -1)
# $$
#
# ---
#
# ## Task 6: Distance Between Branches of Hyperbola $x^2 - y^2 = 1$
#
# 1. **Standard Form**:
#    The equation $x^2 - y^2 = 1$ represents a hyperbola with transverse axis along the $x$-axis.
#
# 2. **Distance Between Branches**:
#    The distance between the asymptotes at any vertical line $x = k$ is given by:
#    $$
#    d = 2|k|
#    $$
#
# 3. **At $x = 0$**:
#    At the center ($x = 0$), the branches are asymptotic.
#
# **Final Answer**: The branches of the hyperbola have an infinite separation at $x = 0$ but can be measured along any vertical slice.
