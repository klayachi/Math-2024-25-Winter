# %% [markdown]
# <a href="https://colab.research.google.com/github/klayachi/Math-2024-25-Winter/blob/main/Notebooks_EN/03_Mathematical_Analysis/12_Derivatives/Extremum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 22. Extremum
#
# 6. The profit function is $P(u) = -2u^2 + 50u - 300$, where $u$ is the number of units sold. Find the number of units that maximize profit.
#
# 7. You have 10 meters of string, and you need to use it to enclose the largest possible rectangular. Find the dimensions of the rectangle.
#
# 8. Find extremum od $f(x) = x^2 + 3x - 5$.
#
# 9. Find extremum of $f(x) =\frac{x^2+2x+1}{x-1}$.

# %% [markdown]
# #**HomeWork :**

# %% [markdown]
# ### 6. Maximizing the Profit Function
#
# The profit function is:
#
# $$ P(u) = -2u^2 + 50u - 300 $$
#
# To find the number of units \( u \) that maximize profit:
#
# - Take the first derivative of \( P(u) \):
#
# $$ P'(u) = \frac{d}{du} \left( -2u^2 + 50u - 300 \right) $$
# $$ P'(u) = -4u + 50 $$
#
# - Set \( P'(u) = 0 \) to find the critical point:
#
# $$ -4u + 50 = 0 $$
# $$ u = \frac{50}{4} = 12.5 $$
#
# - Verify that it is a maximum by checking the second derivative:
#
# $$ P''(u) = -4 $$
#
# Since \( P''(u) < 0 \), the critical point \( u = 12.5 \) is a maximum.
#
# **Result:** The number of units that maximize profit is:
#
# $$ u = 12.5 \; \text{units}. $$
#
# ---
#
# ### 7. Maximizing the Area of a Rectangle with 10 Meters of String
#
# Let \( x \) be the width and \( y \) be the length of the rectangle. The perimeter is:
#
# $$ 2x + 2y = 10 \quad \implies \quad x + y = 5 \quad \implies \quad y = 5 - x $$
#
# The area of the rectangle is:
#
# $$ A = x \cdot y = x(5 - x) = 5x - x^2 $$
#
# To maximize the area:
#
# - Take the derivative of \( A(x) \):
#
# $$ A'(x) = \frac{d}{dx} (5x - x^2) = 5 - 2x $$
#
# - Set \( A'(x) = 0 \) to find the critical point:
#
# $$ 5 - 2x = 0 \quad \implies \quad x = 2.5 $$
#
# - Substitute \( x = 2.5 \) into \( y = 5 - x \):
#
# $$ y = 5 - 2.5 = 2.5 $$
#
# - Verify that it is a maximum by checking the second derivative:
#
# $$ A''(x) = -2 $$
#
# Since \( A''(x) < 0 \), the critical point is a maximum.
#
# **Result:** The dimensions of the rectangle are:
#
# $$ x = 2.5 \, \text{m}, \; y = 2.5 \, \text{m}. $$
#
# ---
#
# ### 8. Extremum of \( f(x) = x^2 + 3x - 5 \)
#
# The function is:
#
# $$ f(x) = x^2 + 3x - 5 $$
#
# - Take the derivative:
#
# $$ f'(x) = 2x + 3 $$
#
# - Set \( f'(x) = 0 \) to find the critical point:
#
# $$ 2x + 3 = 0 \quad \implies \quad x = -\frac{3}{2} $$
#
# - To determine if it is a minimum or maximum, check the second derivative:
#
# $$ f''(x) = 2 $$
#
# Since \( f''(x) > 0 \), the critical point is a minimum.
#
# - The value of \( f(x) \) at \( x = -\frac{3}{2} \) is:
#
# $$ f\left( -\frac{3}{2} \right) = \left( -\frac{3}{2} \right)^2 + 3\left( -\frac{3}{2} \right) - 5 $$
#
# Simplify:
#
# $$ f\left( -\frac{3}{2} \right) = \frac{9}{4} - \frac{9}{2} - 5 = -\frac{29}{4} $$
#
# **Result:** The minimum value is:
#
# $$ x = -\frac{3}{2}, \; f(x) = -\frac{29}{4}. $$
#
# ---
#
# ### 9. Extremum of \( $ f(x) = \frac{x^2 + 2x + 1}{x - 1}$ \)
#
# The function is:
#
# $$ f(x) = \frac{x^2 + 2x + 1}{x - 1} $$
#
# 1. **Take the derivative using the quotient rule**:
#
# $$ f'(x) = \frac{(2x + 2)(x - 1) - (x^2 + 2x + 1)(1)}{(x - 1)^2} $$
#
# Simplify the numerator:
#
# $$ f'(x) = \frac{(2x^2 - 2x + 2x - 2) - (x^2 + 2x + 1)}{(x - 1)^2} $$
#
# Combine like terms:
#
# $$ f'(x) = \frac{2x^2 - 2 - x^2 - 2x - 1}{(x - 1)^2} $$
#
# Simplify further:
#
# $$ f'(x) = \frac{x^2 - 2x - 3}{(x - 1)^2} $$
#
# 2. **Set \( f'(x) = 0 \) to find critical points**:
#
# Solve the numerator:
#
# $$ x^2 - 2x - 3 = 0 $$
#
# Factorize:
#
# $$ (x - 3)(x + 1) = 0 $$
#
# Thus:
#
# $$ x = 3 \quad \text{and} \quad x = -1 $$
#
# 3. **Check for vertical asymptotes**:
#
# The denominator \( (x - 1)^2 \) is undefined at \( x = 1 \), so there is no extremum at \( x = 1 \).
#
# ---
#
# ### Final Results:
#
# - Critical points are at:
#
# $$ x = 3 \; \text{and} \; x = -1. $$
