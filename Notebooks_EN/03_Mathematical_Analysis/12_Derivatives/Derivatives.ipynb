# %% [markdown]
# <a href="https://colab.research.google.com/github/klayachi/Math-2024-25-Winter/blob/main/Notebooks_EN/03_Mathematical_Analysis/12_Derivatives/Derivatives.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 21. Derivatives
#
# 1. Compute derivatives of functions:
#    * $y(x) = -3x+3$
#    * $y(x) = \pi x + \sin(1)$
#    * $y(x) = 4+\sin(2)$
#    * $y(x) = 2x^3 - 3x^2 + 8x - 9$
#    * $y(x) = 6 x^{1/3}$
#    * $y(x) = \sqrt{x}$
#    * $y(x) = \cos(x) + \sin(x)$
#    * $y(x) = 2\sin(x) \cos(x)$
#    * $y(x) = x\sin(x)$
#    * $y(x) = (x+1)(x+1)$
#    * $y(x) = \frac{x}{x+1}$
#    * $y(x) = (x+1)\exp(x)$
#    * $y(x) = \sin(x^2)$
#    * $y(x) = \exp(-2x)$
#    * $y(x) = \frac{1}{\sin(x+1)}$
#    * $y(x) = \sqrt{2x+1}$
#
# 2. Prove:
#    - $\frac{d}{dx} (\ln(\sin(x))) = \cot(x)$
#
# 3. For $f(x) = \cos(x)$, verify that $f''(x) = -f(x)$.
#
# 4. Using de l'Hospital's Rule, find the improper limits:
#    - $\displaystyle \lim_{x\to 0} \frac{\sin{x}}{x}$
#
#    - $\displaystyle \lim_{x\to \infty} \frac{\ln x}{x}$
#
#    - $\displaystyle \lim_{x\to \infty} \frac{\exp(x)}{x}$
#
# 5. In physics, the position of a particle is given by $x(t) = 3t^2 - 6t + 1$. Find the velocity $V(t)=x'(t)$ and acceleration $a(t)=V'(t)=x''(t)$ of the particle at time $t = 2$.

# %% [markdown]
# #**HomeWork :**

# %% [markdown]
# ## **1. Compute Derivatives of Functions**:
#
# ---
#
# ### 1. $y(x) = -3x + 3$
#
# - This is a **linear function**. The derivative of $y(x) = mx + b$ is simply the slope $m$.
# - Here, $m = -3$ and $b = 3$ (a constant, which always has a derivative of $0$).
#
# **Result:**
# $$ y'(x) = -3 $$
#
# ---
#
# ### 2. $y(x) = \pi x + \sin(1)$
#
# - $\pi$ is a constant, so its derivative is $\pi$.
# - $\sin(1)$ is also a constant because it doesn’t depend on $x$. Its derivative is $0$.
#
# **Result:**
# $$ y'(x) = \pi $$
#
# ---
#
# ### 3. $y(x) = 4 + \sin(2)$
#
# - Both $4$ and $\sin(2)$ are constants, so their derivatives are $0$.
#
# **Result:**
# $$ y'(x) = 0 $$
#
# ---
#
# ### 4. $y(x) = 2x^3 - 3x^2 + 8x - 9$
#
# - Use the **power rule**:
#   For $x^n$, the derivative is $nx^{n-1}$.
# - Apply it to each term:
#   - $2x^3 \to 6x^2$
#   - $-3x^2 \to -6x$
#   - $8x \to 8$
#   - $-9$ (constant) $\to 0$
#
# - $y'(x)= (2x^3 - 3x^2 + 8x - 9)'$
# - $y'(x)= (2x^3)' - (3x^2)' + (8x)' - (9)'$
# - $y'(x)= (2'*x^3+2*3x^2) - (3'*x^2 + 3*2x^1) + (8'*x + 8*1x^0) - 0$
# - $y'(x)= 6x^2 - 6x + 8$
#
#
# **Result:**
# $$ y'(x) = 6x^2 - 6x + 8 $$
#
# ---
#
# ### 5. $y(x) = 6x^{1/3}$
#
# - Rewrite the fractional power and use the **power rule**:
#   $$ \frac{d}{dx}[x^n] = n x^{n-1} $$
# - Here, $n = \frac{1}{3}$:
#   $$ y'(x) = 6 \cdot \frac{1}{3}x^{-2/3} $$
#
# Simplify:
# $$ y'(x) = 2x^{-2/3} $$
#
# ---
#
# ### 6. $y(x) = \sqrt{x}$
#
# - Rewrite $\sqrt{x}$ as $x^{1/2}$ and apply the **power rule**:
#   $$ y'(x) = \frac{1}{2}x^{-1/2} $$
#
# Rewrite back into square root form:
# $$ y'(x) = \frac{1}{2\sqrt{x}} $$
#
# ---
#
# ### 7. $y(x) = \cos(x) + \sin(x)$
#
# - The derivative of $\cos(x)$ is $-\sin(x)$.
# - The derivative of $\sin(x)$ is $\cos(x)$.
#
# **Result:**
# $$ y'(x) = -\sin(x) + \cos(x) $$
#
# ---
#
# ### 8. $y(x) = 2\sin(x)\cos(x)$
#
# - Use the **product rule**:
#   $$ \frac{d}{dx}[uv] = u'v + uv' $$
# - Here, $u = 2\sin(x)$ and $v = \cos(x)$.
#   - $u' = 2\cos(x)$
#   - $v' = -\sin(x)$
#
# Now substitute:
# $$ y'(x) = 2\cos(x)\cos(x) + 2\sin(x)(-\sin(x)) $$
#
# Simplify:
# $$ y'(x) = 2[\cos^2(x) - \sin^2(x)] $$
#
# ---
#
# ### 9. $y(x) = x\sin(x)$
#
# - Use the **product rule**:
#   $$ \frac{d}{dx}[uv] = u'v + uv' $$
# - Here, $u = x$ and $v = \sin(x)$:
#   - $u' = 1$
#   - $v' = \cos(x)$
#
# Substitute:
# $$ y'(x) = 1 \cdot \sin(x) + x \cdot \cos(x) $$
#
# Simplify:
# $$ y'(x) = \sin(x) + x\cos(x) $$
#
# ---
#
# ### 10. $y(x) = (x+1)(x+1)$
#
# - Rewrite as $y(x) = (x+1)^2$ and use the **chain rule**:
#   $$ \frac{d}{dx}[f(g(x))] = f'(g(x)) \cdot g'(x) $$
# - Here, $f(x) = x^2$ and $g(x) = x+1$:
#   - $f'(x) = 2x$
#   - $g'(x) = 1$
#
# Substitute:
# $$ y'(x) = 2(x+1) $$
#
# ---
#
# ### 11. $y(x) = \frac{x}{x+1}$
#
# - Use the **quotient rule**:
#   $$ \frac{d}{dx}\left(\frac{u}{v}\right) = \frac{u'v - uv'}{v^2} $$
# - Here, $u = x$ and $v = x+1$:
#   - $u' = 1$
#   - $v' = 1$
#
# Substitute:
# $$ y'(x) = \frac{(x+1)(1) - x(1)}{(x+1)^2} $$
#
# Simplify:
# $$ y'(x) = \frac{1}{(x+1)^2} $$
#
# ---
#
# ### 12. $y(x) = (x+1)\exp(x)$
#
# - Use the **product rule**:
#   $$ y'(x) = (x+1)\frac{d}{dx}[\exp(x)] + \exp(x)\frac{d}{dx}[x+1] $$
# - Simplify:
# $$ y'(x) = \exp(x) + (x+1)\exp(x) $$
#
# Combine terms:
# $$ y'(x) = (x+2)\exp(x) $$
#
# ---
#
# ### 13. $y(x) = \sin(x^2)$
#
# - Use the **chain rule**:
#   $$ y'(x) = \cos(x^2) \cdot \frac{d}{dx}[x^2] $$
# - Simplify:
# $$ y'(x) = 2x\cos(x^2) $$
#
# ---
#
# ### 14. $y(x) = \exp(-2x)$
#
# - Use the **chain rule**:
#   $$ y'(x) = \exp(-2x) \cdot (-2) $$
# - Simplify:
# $$ y'(x) = -2\exp(-2x) $$
#
# ---
#
# ### 15. $y(x) = \frac{1}{\sin(x+1)}$
#
# - Rewrite as $y(x) = [\sin(x+1)]^{-1}$ and use the **chain rule**:
#   $$ y'(x) = -\frac{\cos(x+1)}{\sin^2(x+1)} $$
#
# ---
#
# ### 16. $y(x) = \sqrt{2x+1}$
#
# - Rewrite as $y(x) = (2x+1)^{1/2}$ and use the **chain rule**:
#   $$ y'(x) = \frac{1}{2\sqrt{2x+1}} \cdot \frac{d}{dx}[2x+1] $$
# - Simplify:
# $$ y'(x) = \frac{1}{\sqrt{2x+1}} $$
#
# ---
#
# ## **2. Prove:**
#    $$ \frac{d}{dx} (\ln(\sin(x))) = \cot(x) $$
#
#    - Using the chain rule:
#    $$
#    \frac{d}{dx} [\ln(\sin(x))] = \frac{1}{\sin(x)} \cdot \cos(x)
#    $$
#    Simplify:
#    $$
#    \frac{\cos(x)}{\sin(x)} = \cot(x)
#    $$
#
# ---
#
# ##**3. Verify for \( f(x) = \cos(x) \):**
#    - First derivative:
#    $$
#    f'(x) = -\sin(x)
#    $$
#    - Second derivative:
#    $$
#    f''(x) = -\cos(x)
#    $$
#    Thus:
#    $$
#    f''(x) = -f(x)
#    $$
#
# ---
#
# ### 4. Using de l'Hospital's Rule, Find Limits
#
# 1. $$ \lim_{x\to 0} \frac{\sin{x}}{x} $$
#    - Apply L'Hospital's Rule:
#    $$
#    \lim_{x\to 0} \frac{\sin{x}}{x} = \frac{\cos(x)}{1} = 1
#    $$
#
# 2. $$ \lim_{x\to \infty} \frac{\ln x}{x} $$
#    - Apply L'Hospital's Rule:
#    $$
#    \lim_{x\to \infty} \frac{\ln x}{x} = \frac{\frac{1}{x}}{1} = 0
#    $$
#
# 3. $$ \lim_{x\to \infty} \frac{\exp(x)}{x} $$
#    - Apply L'Hospital's Rule:
#    $$
#    \lim_{x\to \infty} \frac{\exp(x)}{x} = \infty
#    $$
#
# ---
#
# ### 5. Physics: Position, Velocity, and Acceleration
#
# Given:
# $$ x(t) = 3t^2 - 6t + 1 $$
#
# - **Velocity** \( V(t) = x'(t) \):
#    $$
#    V(t) = \frac{d}{dt} [3t^2 - 6t + 1] = 6t - 6
#    $$
#
# - **Acceleration** \( a(t) = x''(t) \):
#    $$
#    a(t) = \frac{d}{dt} [6t - 6] = 6
#    $$
#
# - At \( t = 2 \):
#    $$
#    V(2) = 6(2) - 6 = 6, \quad a(2) = 6
#    $$
#
# ---
#
# ### Final Results:
# - Velocity at \( t = 2 \): \( V(2) = 6 \)
# - Acceleration at \( t = 2 \): \( a(2) = 6 \)
